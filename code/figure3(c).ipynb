# %%
import yaml
import importlib
from module_nlp.core import fasttext_space

# %% [markdown]
# # Figure supp3C

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_sighted.yml") as f:
    config = yaml.safe_load(f)

_ = fasttext_space.coloremotion_associate(config['coloremotion_associate'], fig_number=["supp5A", "supp5B", "supp5C", "supp5D"])

# %%
# !./module_nlp/core/plots_it.R "rdm_osgood_both"

# Display svg images
from IPython.display import SVG
display(SVG("../figures/supp5E.svg"))
