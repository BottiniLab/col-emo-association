# %%
import yaml
import importlib
from module_nlp.core import fasttext_space

# %% [markdown]
# ## Figure supp4A-B
# ### Compute coordinates in control geographic space

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_sighted.yml") as f:
    config = yaml.safe_load(f)

df = fasttext_space.get_wheels(config['get_control_wheel'])

# %% [markdown]
# ### Generate RDMs for control conditions

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_sighted.yml") as f:
    config = yaml.safe_load(f)

fasttext_space.control_rdm(config['control_rdm'])

# %% [markdown]
# ### Run correlation analysis for sighted participants

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_sighted.yml") as f:
    config = yaml.safe_load(f)

fasttext_space.osgood_rdm(config['rdm_difference'], fig_number=["supp4A", "supp4B", "supp4C", "supp4D",
                                                                "supp4E", "supp4F", "supp4G", "supp4H"])
# Out:
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# !./module_nlp/core/plots_it.R "rdm_osgood_col"
# !./module_nlp/core/plots_it.R "rdm_osgood_em"

# Display svg images
from IPython.display import SVG
display(SVG("../figures/supp4I.svg"))
display(SVG("../figures/supp4L.svg"))
