# %%
import yaml
import importlib
from module_nlp.core import fasttext_space

# %% [markdown]
# # Figures supp6
# ## Compute RDMs for control conditions

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_blind.yml") as f:
    config = yaml.safe_load(f)

fasttext_space.control_rdm(config['control_rdm'])

# %% [markdown]
# ## Run correlation analysis for blind participants

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_blind.yml") as f:
    config = yaml.safe_load(f)

fasttext_space.osgood_rdm(config['rdm_difference'], fig_number=["supp6A", "supp6B", "supp6C", "supp6D",
                                                                "supp6E", "supp6F", "supp6G", "supp6H"])
# Out:
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/mattia.silvestri-1/anaconda3/envs/coloremotion/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1477: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
# ...

# %%
# !./module_nlp/core/plots_it.R "rdm_osgood_col_blind"
# !./module_nlp/core/plots_it.R "rdm_osgood_em_blind"

# Display svg images
from IPython.display import SVG
display(SVG("../figures/supp6I.svg"))
display(SVG("../figures/supp6L.svg"))

# %% [markdown]
# # Figure supp2C

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_blind.yml") as f:
    config = yaml.safe_load(f)

_ = fasttext_space.coloremotion_associate(config['coloremotion_associate'])

# %%
# !./module_nlp/core/plots_it.R "rdm_osgood_both_blind"

# Display svg images
from IPython.display import SVG
display(SVG("../figures/supp2C.svg"))
