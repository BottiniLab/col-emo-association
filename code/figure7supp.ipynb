# %%
import yaml
import importlib
from module_nlp.core import fasttext_space

# %% [markdown]
# # Figure supp7

# %%
_ = importlib.reload(fasttext_space)
with open("./module_nlp/config/config_blind.yml") as f:
    config = yaml.safe_load(f)

_ = fasttext_space.coloremotion_associate(config['coloremotion_associate'], fig_number=["supp7A", "supp7B", "supp7C", "supp7D"])

# %%
# !./module_nlp/core/plots_it.R "rdm_osgood_both_blind"

# Display svg images
from IPython.display import SVG
display(SVG("../figures/supp7E.svg"))
